# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.13.0
# aiohttp                       3.7.4
# appdirs                       1.4.4
# astor                         0.8.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 3.0.1
# attrs                         21.2.0
# audioread                     3.0.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# blinker                       1.4
# brotlipy                      0.7.0
# cached-property               1.5.2
# cachetools                    4.2.2
# certifi                       2022.5.18.1
# cffi                          1.14.6
# chardet                       3.0.4
# click                         8.0.1
# colorama                      0.4.4
# coverage                      5.5
# cryptography                  3.4.7
# cycler                        0.11.0
# ...
